# %% [markdown]
# # Checkpoint 与性能评估
# 使用 checkpoint 进行性能评估在学术界和工业界都有广泛应用。为了生成 checkpoint，我们首先需要准备 NEMU 环境，并得到 GCPT restorer

# %% [markdown]
# 本节中会用到一些与 `xs-env/env.sh` 不同的路径和常量，为了方便使用，我们创建了一个 `07-checkpoint-env.sh`，在本节中我们将使用该脚本设置环境变量，您可以运行下面的单元格查看这些环境变量。在后续的单元格中我们仍将输出重定向到 `/dev/null` 减少干扰。

# %%
# %%bash
# source 07-checkpoint-env.sh
# Out:
# === xs-env ===
# SET XS_PROJECT_ROOT: /home/guest/xs-env
# SET NOOP_HOME (XiangShan RTL Home): /home/guest/xs-env/XiangShan
# SET NEMU_HOME: /home/guest/xs-env/NEMU
# SET AM_HOME: /home/guest/xs-env/nexus-am
# SET DRAMSIM3_HOME: /home/guest/xs-env/DRAMsim3
# SET gem5_home: /home/guest/xs-env/gem5
# SET TUTORIAL_HOME: /home/guest/xs-env/tutorial
# SET READY2RUN_HOME: /home/guest/xs-env/tutorial/ready-to-run
# /home/guest/xs-env/tutorial
# === checkpoint-env ===
# SET WORKLOAD: stream_100000
# SET CHECKPOINT_INTERVAL: 50000000
# SET SIMPOINT_HOME: /home/guest/xs-env/tutorial/07-checkpoint
# SET PAYLOAD_PATH: /home/guest/xs-env/tutorial/ready-to-run/07-checkpoint
# SET GCPT_PATH: /home/guest/xs-env/tutorial/07-checkpoint/gcpt
# SET LOG_PATH: /home/guest/xs-env/tutorial/07-checkpoint/logs
# SET RESULT_PATH: /home/guest/xs-env/tutorial/07-checkpoint/result
# SET PROFILING_RESULT_PATH: /home/guest/xs-env/tutorial/07-checkpoint/result/profiling
# SET NEMU: /home/guest/xs-env/NEMU/build/riscv64-nemu-interpreter
# SET GCPT: /home/guest/xs-env/tutorial/07-checkpoint/gcpt/build/gcpt.bin
# SET SIMPOINT: /home/guest/xs-env/NEMU/resource/simpoint/simpoint_repo/bin/simpoint

# %%
# %%bash
# source 07-checkpoint-env.sh >/dev/null
#
# cd ${NEMU_HOME}
# git submodule update --init
#
# # 编译 simpoint
# cd ${NEMU_HOME}/resource/simpoint/simpoint_repo
# make clean
# make
#
# # 编译 NEMU
# cd ${NEMU_HOME}
# make clean
# make riscv64-xs-cpt_defconfig
# make -j8
#
# cd ${NEMU_HOME}/resource/gcpt_restore
# rm -rf ${GCPT_PATH}
# make -C ${NEMU_HOME}/resource/gcpt_restore/ O=${GCPT_PATH} GCPT_PAYLOAD_PATH=${PAYLOAD_PATH}/${WORKLOAD}.bin CROSS_COMPILE=riscv64-linux-gnu-
# Out:
# make -C analysiscode clean
# make[1]: Entering directory '/home/guest/xs-env/NEMU/resource/simpoint/simpoint_repo/analysiscode'
# rm -f CmdLineParser.o Datapoint.o Dataset.o FVParser.o KMeans.o Logger.o Simpoint.o SimpointOptions.o Utilities.o CmdLineParser.d Datapoint.d Dataset.d FVParser.d KMeans.d Logger.d Simpoint.d SimpointOptions.d Utilities.d core simpoint
# make[1]: Leaving directory '/home/guest/xs-env/NEMU/resource/simpoint/simpoint_repo/analysiscode'
# rm -f bin/simpoint
# make -C analysiscode
# make[1]: Entering directory '/home/guest/xs-env/NEMU/resource/simpoint/simpoint_repo/analysiscode'
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 Utilities.cpp \
# | sed 's/\(Utilities\)\.o[ :]*/\1.o Utilities.d : /g' > Utilities.d; \
# [ -s Utilities.d ] || rm -f Utilities.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 SimpointOptions.cpp \
# | sed 's/\(SimpointOptions\)\.o[ :]*/\1.o SimpointOptions.d : /g' > SimpointOptions.d; \
# [ -s SimpointOptions.d ] || rm -f SimpointOptions.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 Simpoint.cpp \
# | sed 's/\(Simpoint\)\.o[ :]*/\1.o Simpoint.d : /g' > Simpoint.d; \
# [ -s Simpoint.d ] || rm -f Simpoint.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 Logger.cpp \
# | sed 's/\(Logger\)\.o[ :]*/\1.o Logger.d : /g' > Logger.d; \
# [ -s Logger.d ] || rm -f Logger.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 KMeans.cpp \
# | sed 's/\(KMeans\)\.o[ :]*/\1.o KMeans.d : /g' > KMeans.d; \
# [ -s KMeans.d ] || rm -f KMeans.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 FVParser.cpp \
# | sed 's/\(FVParser\)\.o[ :]*/\1.o FVParser.d : /g' > FVParser.d; \
# [ -s FVParser.d ] || rm -f FVParser.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 Dataset.cpp \
# | sed 's/\(Dataset\)\.o[ :]*/\1.o Dataset.d : /g' > Dataset.d; \
# [ -s Dataset.d ] || rm -f Dataset.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 Datapoint.cpp \
# | sed 's/\(Datapoint\)\.o[ :]*/\1.o Datapoint.d : /g' > Datapoint.d; \
# [ -s Datapoint.d ] || rm -f Datapoint.d
# set -e; g++ -MM -Wall -pedantic -pedantic-errors -O3 -std=c++11 CmdLineParser.cpp \
# | sed 's/\(CmdLineParser\)\.o[ :]*/\1.o CmdLineParser.d : /g' > CmdLineParser.d; \
# [ -s CmdLineParser.d ] || rm -f CmdLineParser.d
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o CmdLineParser.o CmdLineParser.cpp
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o Datapoint.o Datapoint.cpp
# Datapoint.cpp: In member function ‘void Datapoint::read(FILE*)’:
# Datapoint.cpp:215:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   215 |     fscanf(in, "%u", &length);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~
# Datapoint.cpp:223:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   223 |         fscanf(in, "%lf", &(*this)[i]);
#       |         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~
# Datapoint.cpp: In member function ‘void Datapoint::readBinary(FILE*)’:
# Datapoint.cpp:252:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   252 |     fread((void *)&length, sizeof(unsigned int), 1, in);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Datapoint.cpp:255:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   255 |     fread((void *)&(*b), sizeof(double), length, in);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o Dataset.o Dataset.cpp
# Dataset.cpp: In member function ‘void Dataset::read(FILE*)’:
# Dataset.cpp:174:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   174 |     fscanf(in, "%u", &length);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~
# Dataset.cpp:189:19: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   189 |             fscanf(in, "%lf", &weight);
#       |             ~~~~~~^~~~~~~~~~~~~~~~~~~~
# Dataset.cpp: In member function ‘void Dataset::readBinary(FILE*)’:
# Dataset.cpp:251:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ��warn_unused_result’ [-Wunused-result]
#   251 |     fread((void *)&length, sizeof(unsigned int), 1, in);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Dataset.cpp:254:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   254 |     fread((void *)&hasWeights, sizeof(unsigned int), 1, in);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Dataset.cpp:261:18: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   261 |             fread((void *)&weight, sizeof(double), 1, in);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o FVParser.o FVParser.cpp
# FVParser.cpp: In member function ‘bool FVParser::nextLine(std::__cxx11::list<FVParserToken>*)’:
# FVParser.cpp:106:14: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   106 |         fgets(buffer, BUF_SIZE, input);
#       |         ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o KMeans.o KMeans.cpp
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o Logger.o Logger.cpp
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o Simpoint.o Simpoint.cpp
# g++  -Wall -pedantic -pedantic-errors -o SimpointOptions.o -c SimpointOptions.cpp -std=c++11
# g++  -Wall -pedantic -pedantic-errors -O3 -std=c++11  -c -o Utilities.o Utilities.cpp
# g++ -Wall -pedantic -pedantic-errors -O3 -std=c++11 CmdLineParser.o Datapoint.o Dataset.o FVParser.o KMeans.o Logger.o Simpoint.o SimpointOptions.o Utilities.o -o simpoint
# cp simpoint ../bin/.
# make[1]: Leaving directory '/home/guest/xs-env/NEMU/resource/simpoint/simpoint_repo/analysiscode'
# rm -rf /home/guest/xs-env/NEMU/build
# + CC src/nemu-main.c
# + CC src/device/device.c
# + CC src/device/alarm.c
# + CC src/device/intr.c
# + CC src/device/plic.c
# + CC src/device/uartlite.c
# + CC src/device/keyboard.c
# + CC src/device/vga.c
# + CC src/device/sdcard.c
# + CC src/cpu/cpu-exec.c
# + CC src/cpu/difftest/dut.c
# + CC src/cpu/difftest/ref.c
# + CC src/cpu/tcache.c
# + CC src/monitor/image_loader.c
# + CC src/monitor/aligncheck.c
# + CC src/monitor/monitor.c
# + CC src/monitor/ui.c
# + CC src/monitor/watchpoint.c
# + CC src/utils/br_log.c
# + CC src/utils/dynamic-config.c
# + CC src/utils/expr.c
# + CC src/utils/filename.c
# + CC src/utils/iqueue.c
# + CC src/utils/log.c
# + CC src/utils/state.c
# + CC src/utils/timer.c
# + CC src/memory/host-tlb.c
# + CC src/memory/paddr.c
# + CC src/memory/vaddr.c
# + CC src/isa/riscv64/clint.c
# + CC src/isa/riscv64/difftest/dut.c
# + CC src/isa/riscv64/difftest/ref.c
# + CC src/isa/riscv64/init.c
# + CC src/isa/riscv64/instr/decode.c
# + CC src/isa/riscv64/instr/fp.c
# + CC src/isa/riscv64/instr/priv/system.c
# + CC src/isa/riscv64/instr/rva/amo.c
# + CC src/isa/riscv64/instr/rvcbo/cbo_impl.c
# + CC src/isa/riscv64/instr/rvk/aes_common.c
# + CC src/isa/riscv64/instr/rvv/vcommon.c
# + CC src/isa/riscv64/instr/rvv/vcompute_impl.c
# + CC src/isa/riscv64/instr/rvv/vldst_impl.c
# + CC src/isa/riscv64/instr/rvv/vreg_impl.c
# + CC src/isa/riscv64/instr/vp.c
# + CC src/isa/riscv64/logo.c
# + CC src/isa/riscv64/reg.c
# + CC src/isa/riscv64/system/aia.c
# + CC src/isa/riscv64/system/intr.c
# + CC src/isa/riscv64/system/mmu.c
# + CC src/isa/riscv64/system/priv.c
# + CC src/isa/riscv64/system/timer.c
# + CC src/isa/riscv64/system/trigger.c
# + CC src/engine/interpreter/fp.c
# + CC src/engine/interpreter/hostcall.c
# + CC src/engine/interpreter/init.c
# + CC src/device/io/map.c
# + CC src/device/io/mmio.c
# + CC src/device/io/port-io.c
# + CC src/profiling/profiling_control.c
# + CC src/checkpoint/cpt_env.c
# + CXX src/checkpoint/path_manager.cpp
# + CXX src/checkpoint/semantic_point.cpp
# + CXX src/checkpoint/serializer.cpp
# + CXX src/checkpoint/simpoint.cpp
# + CXX src/base/output.cpp
# + CXX src/iostream3/zfstream.cpp
# + CXX src/memory/store_queue_wrapper.cpp
# + ccache g++ /home/guest/xs-env/NEMU/build/riscv64-nemu-interpreter
# make: Entering directory '/home/guest/xs-env/NEMU/resource/gcpt_restore'
# + AS src/restore.S
# + LD /home/guest/xs-env/tutorial/07-checkpoint/gcpt/build/gcpt
# make: Leaving directory '/home/guest/xs-env/NEMU/resource/gcpt_restore'

# %% [markdown]
# 接下来，我们需要使用 NEMU 运行要进行切片的程序，来收集程序行为

# %%
# %%bash
# source 07-checkpoint-env.sh >/dev/null
#
# rm -rf $RESULT_PATH
#
# _LOG_PATH=$LOG_PATH/profiling
# mkdir -p $_LOG_PATH
#
# # 使用 GCPT 作为镜像
# # -w：要加载的实际负载为 WORKLOAD
# # -C：使用 profiling 配置运行 NEMU
# $NEMU ${GCPT} \
#     -D ${RESULT_PATH} \
#     -w ${WORKLOAD} \
#     -C profiling \
#     -b \
#     --simpoint-profile \
#     --cpt-interval ${CHECKPOINT_INTERVAL} \
#     > >(tee ${_LOG_PATH}/${WORKLOAD}-out.txt) 2> >(tee ${_LOG_PATH}/${WORKLOAD}-err.txt)
# Out:
# OpenSBI v1.5-23-gb9c091e
#    ____                    _____ ____ _____
#   / __ \                  / ____|  _ \_   _|
#  | |  | |_ __   ___ _ __ | (___ | |_) || |
#  | |  | | '_ \ / _ \ '_ \ \___ \|  _ < | |
#  | |__| | |_) |  __/ | | |____) | |_) || |_
#   \____/| .__/ \___|_| |_|_____/|____/_____|
#         | |
#         |_|
#
# Platform Name             : freechips,rocketchip-unknown
# Platform Features         : medeleg
# Platform HART Count       : 1
# Platform IPI Device       : aclint-mswi
# Platform Timer Device     : aclint-mtimer @ 1000000Hz
# Platform Console Device   : xlnx-uartlite
# Platform HSM Device       : ---
# Platform PMU Device       : ---
# Platform Reboot Device    : ---
# Platform Shutdown Device  : ---
# Platform Suspend Device   : ---
# Platform CPPC Device      : ---
# Firmware Base             : 0x80100000
# Firmware Size             : 327 KB
# Firmware RW Offset        : 0x40000
# Firmware RW Size          : 71 KB
# Firmware Heap Offset      : 0x49000
# Firmware Heap Size        : 35 KB (total), 2 KB (reserved), 9 KB (used), 23 KB (free)
# Firmware Scratch Size     : 4096 B (total), 408 B (used), 3688 B (free)
# Runtime SBI Version       : 2.0
#
# Domain0 Name              : root
# Domain0 Boot HART         : 0
# Domain0 HARTs             : 0*
# Domain0 Region00          : 0x0000000038000000-0x000000003800ffff M: (I,R,W) S/U: ()
# Domain0 Region01          : 0x0000000080140000-0x000000008015ffff M: (R,W) S/U: ()
# Domain0 Region02          : 0x0000000080100000-0x000000008013ffff M: (R,X) S/U: ()
# Domain0 Region03          : 0x000000003c000000-0x000000003fffffff M: (I,R,W) S/U: (R,W)
# Domain0 Region04          : 0x0000000000000000-0xffffffffffffffff M: () S/U: (R,W,X)
# Domain0 Next Address      : 0x0000000080200000
# Domain0 Next Arg1         : 0x0000000082300000
# Domain0 Next Mode         : S-mode
# Domain0 SysReset          : yes
# Domain0 SysSuspend        : yes
#
# Boot HART ID              : 0
# Boot HART Domain          : root
# Boot HART Priv Version    : v1.12
# Boot HART Base ISA        : rv64imafdcbvh
# Boot HART ISA Extensions  : smstateen,sscofpmf,sstc,zicntr
# Boot HART PMP Count       : 16
# Boot HART PMP Granularity : 12 bits
# Boot HART PMP Address Bits: 46
# Boot HART MHPM Info       : 0 (0x00000000)
# Boot HART Debug Triggers  : 0 triggers
# Boot HART MIDELEG         : 0x0000000000003666
# Boot HART MEDELEG         : 0x0000000000f0b509
# [    0.000000] Linux version 6.10.3 (liuzehao@open27) (riscv64-unknown-linux-gnu-gcc (g05b95238be6-dirty) 15.0.0 20240611 (experimental), GNU ld (GNU Binutils) 2.42) #12 SMP Sat Aug 17 17:30:08 CST 2024
# [    0.000000] Machine model: freechips,rocketchip-unknown
# [    0.000000] SBI specification v2.0 detected
# [    0.000000] SBI implementation ID=0x1 Version=0x10005
# [    0.000000] SBI TIME extension detected
# [    0.000000] SBI IPI extension detected
# [    0.000000] SBI RFENCE extension detected
# [    0.000000] SBI DBCN extension detected
# [    0.000000] earlycon: sbi0 at I/O port 0x0 (options '')
# [    0.000000] printk: legacy bootconsole [sbi0] enabled
# [    0.000000] efi: UEFI not found.
# [    0.000000] OF: reserved mem: 0x0000000080100000..0x000000008013ffff (256 KiB) nomap non-reusable mmode_resv1@80100000
# [    0.000000] OF: reserved mem: 0x0000000080140000..0x000000008015ffff (128 KiB) nomap non-reusable mmode_resv0@80140000
# [    0.000000] Zone ranges:
# [    0.000000]   DMA32    [mem 0x0000000080000000-0x00000000ffffffff]
# [    0.000000]   Normal   [mem 0x0000000100000000-0x000000027fffffff]
# [    0.000000] Movable zone start for each node
# [    0.000000] Early memory node ranges
# [    0.000000]   node   0: [mem 0x0000000080000000-0x00000000800fffff]
# [    0.000000]   node   0: [mem 0x0000000080100000-0x000000008015ffff]
# [    0.000000]   node   0: [mem 0x0000000080160000-0x000000027fffffff]
# [    0.000000] Initmem setup node 0 [mem 0x0000000080000000-0x000000027fffffff]
# [    0.000000] SBI HSM extension detected
# [    0.000000] Falling back to deprecated "riscv,isa"
# [    0.000000] riscv: base ISA extensions acdfhimv
# [    0.000000] riscv: ELF capabilities acdfimv
# [    0.000000] percpu: Embedded 13 pages/cpu s23648 r0 d29600 u53248
# [    0.000000] Kernel command line: console=hvc0 earlycon=sbi
# [    0.000000] Dentry cache hash table entries: 1048576 (order: 11, 8388608 bytes, linear)
# [    0.000000] Inode-cache hash table entries: 524288 (order: 10, 4194304 bytes, linear)
# [    0.000000] Built 1 zonelists, mobility grouping on.  Total pages: 2097152
# [    0.000000] mem auto-init: stack:all(zero), heap alloc:off, heap free:off
# [    0.000000] software IO TLB: area num 1.
# [    0.000000] software IO TLB: mapped [mem 0x00000000fbfff000-0x00000000fffff000] (64MB)
# [    0.000000] Memory: 8180520K/8388608K available (2005K kernel code, 4301K rwdata, 2048K rodata, 4141K init, 141K bss, 208088K reserved, 0K cma-reserved)
# [    0.000000] SLUB: HWalign=64, Order=0-3, MinObjects=0, CPUs=1, Nodes=1
# [    0.000000] rcu: Hierarchical RCU implementation.
# [    0.000000] rcu: 	RCU restricting CPUs from NR_CPUS=64 to nr_cpu_ids=1.
# [    0.000000] rcu: RCU calculated value of scheduler-enlistment delay is 25 jiffies.
# [    0.000000] rcu: Adjusting geometry for rcu_fanout_leaf=16, nr_cpu_ids=1
# [    0.000000] NR_IRQS: 64, nr_irqs: 64, preallocated irqs: 0
# [    0.000000] riscv-intc: 64 local interrupts mapped
# [    0.000000] riscv: providing IPIs using SBI IPI extension
# [    0.000000] rcu: srcu_init: Setting srcu_struct sizes based on contention.
# [    0.000000] clocksource: riscv_clocksource: mask: 0xffffffffffffffff max_cycles: 0x1d854df40, max_idle_ns: 3526361616960 ns
# [    0.000003] sched_clock: 64 bits at 1000kHz, resolution 1000ns, wraps every 2199023255500ns
# [    0.000623] Console: colour dummy device 80x25
# [    0.000794] Calibrating delay loop (skipped), value calculated using timer frequency.. 2.00 BogoMIPS (lpj=4000)
# [    0.000922] pid_max: default: 32768 minimum: 301
# [    0.001485] Mount-cache hash table entries: 16384 (order: 5, 131072 bytes, linear)
# [    0.001742] Mountpoint-cache hash table entries: 16384 (order: 5, 131072 bytes, linear)
# [    0.006820] riscv: ELF compat mode unsupported
# [    0.006866] ASID allocator using 16 bits (65536 entries)
# [    0.007379] rcu: Hierarchical SRCU implementation.
# [    0.007445] rcu: 	Max phase no-delay instances is 1000.
# [    0.008954] EFI services will not be available.
# [    0.009406] smp: Bringing up secondary CPUs ...
# [    0.009486] smp: Brought up 1 node, 1 CPU
# [    0.011648] clocksource: jiffies: mask: 0xffffffff max_cycles: 0xffffffff, max_idle_ns: 7645041785100000 ns
# [    0.011789] futex hash table entries: 256 (order: 2, 16384 bytes, linear)
# [    0.012052] DMA: preallocated 1024 KiB GFP_KERNEL pool for atomic allocations
# [    0.012262] DMA: preallocated 1024 KiB GFP_KERNEL|GFP_DMA32 pool for atomic allocations
# [    0.037170] cpu0: rdtime lacks granularity needed to measure unaligned access speed
# [    0.041728] clocksource: Switched to clocksource riscv_clocksource
# [    0.056190] workingset: timestamp_bits=62 max_order=21 bucket_order=0
# [    0.147321] riscv-plic 3c000000.interrupt-controller: mapped 64 interrupts with 1 handlers for 2 contexts.
# [    0.149086] printk: legacy console [hvc0] enabled
# [    0.149086] printk: legacy console [hvc0] enabled
# [    0.149237] printk: legacy bootconsole [sbi0] disabled
# [    0.149237] printk: legacy bootconsole [sbi0] disabled
# [    0.149481] Serial: 8250/16550 driver, 4 ports, IRQ sharing disabled
# [    0.152345] 40600000.serial: ttyUL0 at MMIO 0x40600000 (irq = 12, base_baud = 0) is a uartlite
# [    0.152686] uartlite 40600000.serial: Runtime PM usage count underflow!
# [    0.158742] clk: Disabling unused clocks
# [    0.756215] Freeing unused kernel image (initmem) memory: 4140K
# [    0.756355] Run /init as init process
# /
# bin          init         mnt          sbin         tmp
# dev          lib          proc         spec_common  usr
# etc          linuxrc      root         sys          var
# 12345
# -------------------------------------------------------------
# STREAM version $Revision: 5.10 $
# -------------------------------------------------------------
# This system uses 4 bytes per array element.
# -------------------------------------------------------------
# Array size = 10000000 (elements), Offset = 0 (elements)
# Memory per array = 38.1 MiB (= 0.0 GiB).
# Total memory required = 114.4 MiB (= 0.1 GiB).
# Each kernel will be executed 5 times.
#  The *best* time for each kernel (excluding the first iteration)
#  will be used to compute the reported bandwidth.
# -------------------------------------------------------------
# Your clock granularity/precision appears to be 511 microseconds.
# Each test below will take on the order of 351242 microseconds.
#    (= 687 clock ticks)
# Increase the size of the arrays if this shows that
# you are not getting at least 20 clock ticks per test.
# -------------------------------------------------------------
# WARNING -- The above is only a rough guideline.
# For best results, please be sure you know the
# precision of your system timer.
# -------------------------------------------------------------
# Function    Best Rate MB/s  Avg time     Min time     Max time
# Copy:            4595.3     0.017409     0.017409     0.017410
# Scale:            455.5     0.175621     0.175621     0.175622
# Add:              559.3     0.214919     0.214535     0.215047
# Triad:            559.4     0.214662     0.214534     0.215046
# -------------------------------------------------------------
# Solution Validates: avg error less than 1.000000e-06 on all three arrays
# -------------------------------------------------------------
# [src/monitor/monitor.c:224,parse_args] Doing Simpoint Profiling
# [src/checkpoint/path_manager.cpp:55,init] Cpt id: -1
# [src/checkpoint/path_manager.cpp:73,setSimpointProfilingOutputDir] Created /home/guest/xs-env/tutorial/07-checkpoint/result/profiling/stream_100000/
#
# [src/checkpoint/simpoint.cpp:84,init] Doing simpoint profiling with interval 50000000
# [src/checkpoint/serializer.cpp:599,next_index] set next index 0
# [src/checkpoint/path_manager.cpp:92,setCheckpointingOutputDir] donot set checkpoint path without Checkpoint mode
# [src/isa/riscv64/init.c:229,init_isa] NEMU will start from pc 0x80000000
# [src/device/io/port-io.c:35,add_pio_map_with_diff] Add port-io map 'uartlite' at [0x00000000000003f8, 0x0000000000000404]
# [src/device/io/port-io.c:35,add_pio_map_with_diff] Add port-io map 'screen' at [0x0000000000000100, 0x0000000000000107]
# [src/device/io/port-io.c:35,add_pio_map_with_diff] Add port-io map 'keyboard' at [0x0000000000000060, 0x0000000000000063]
# [src/device/sdcard.c:137,init_sdcard] Can not find sdcard image:
# [src/monitor/image_loader.c:204,load_img] Loading image (checkpoint/bare metal app/bbl) form cmdline: /home/guest/xs-env/tutorial/07-checkpoint/gcpt/build/gcpt.bin
#
# [src/monitor/image_loader.c:260,load_img] Read 14937112 bytes from file /home/guest/xs-env/tutorial/07-checkpoint/gcpt/build/gcpt.bin to 0x0x100000000
# [src/monitor/monitor.c:63,welcome] Debug: OFF
# [src/monitor/monitor.c:68,welcome] Build time: 13:39:00, Jul 14 2025
# Welcome to riscv64-NEMU!
# For help, type "help"
# [/home/guest/xs-env/NEMU/src/isa/riscv64/include/../instr/special.h:38,execute] nemu_trap case 100
# [src/isa/riscv64/system/priv.c:1898,disable_time_intr] Disabled machine/supervisor/virtualized-supervisor time interruption
#
# [/home/guest/xs-env/NEMU/src/isa/riscv64/include/../instr/special.h:38,execute] nemu_trap case 101
# [src/profiling/profiling_control.c:22,start_profiling] Start profiling. Setting inst count base to Current inst count 269441690.
# [/home/guest/xs-env/NEMU/src/isa/riscv64/include/../instr/special.h:38,execute] nemu_trap case 0
# [src/cpu/cpu-exec.c:916,cpu_exec] nemu: HIT GOOD TRAP at pc = 0x00000000000103b4
# [src/cpu/cpu-exec.c:922,cpu_exec] trap code:0
# [src/cpu/cpu-exec.c:155,monitor_statistic] host time spent = 8634315 us
# [src/cpu/cpu-exec.c:157,monitor_statistic] total guest instructions = 925335065
# [src/cpu/cpu-exec.c:158,monitor_statistic] vst count = 46588127, vst unit count = 46588127, vst unit optimized count = 41363440
# [src/cpu/cpu-exec.c:161,monitor_statistic] simulation frequency = 107169481 instr/s
# [src/utils/state.c:30,is_exit_status_bad] NEMU exit with good state: 2, halt ret: 0

# %% [markdown]
# TODO

# %%
# %%bash
# source 07-checkpoint-env.sh >/dev/null
#
# CLUSTER=${RESULT_PATH}/cluster/${WORKLOAD}
# mkdir -p ${CLUSTER}
#
# random1=`head -20 /dev/urandom | cksum | cut -c 1-6`
# random2=`head -20 /dev/urandom | cksum | cut -c 1-6`
#
# _LOG_PATH=$LOG_PATH/cluster
# mkdir -p $_LOG_PATH
#
# $SIMPOINT \
#     -loadFVFile ${PROFILING_RESULT_PATH}/${WORKLOAD}/simpoint_bbv.gz \
#     -saveSimpoints ${CLUSTER}/simpoints0 \
#     -saveSimpointWeights ${CLUSTER}/weights0 \
#     -inputVectorsGzipped \
#     -maxK 3 \
#     -numInitSeeds 2 \
#     -iters 1000 \
#     -seedkm ${random1} \
#     -seedproj ${random2} \
#     > >(tee ${_LOG_PATH}/${WORKLOAD}-out.txt) 2> >(tee ${_LOG_PATH}/${WORKLOAD}-err.txt)
# Out:
# Command-line: "/home/guest/xs-env/NEMU/resource/simpoint/simpoint_repo/bin/simpoint -loadFVFile /home/guest/xs-env/tutorial/07-checkpoint/result/profiling/stream_100000/simpoint_bbv.gz -saveSimpoints /home/guest/xs-env/tutorial/07-checkpoint/result/cluster/stream_100000/simpoints0 -saveSimpointWeights /home/guest/xs-env/tutorial/07-checkpoint/result/cluster/stream_100000/weights0 -inputVectorsGzipped -maxK 3 -numInitSeeds 2 -iters 1000 -seedkm 353540 -seedproj 529570"
# Using these options (*** indicates user-specified option):
# *** -loadFVFile : /home/guest/xs-env/tutorial/07-checkpoint/result/profiling/stream_100000/simpoint_bbv.gz
#     -k : search
# *** -iters : 1000
#     -dim : 15
# *** -maxK : 3
# *** -numInitSeeds : 2
#     -coveragePct : 1
#     -bicThreshold : 0.9
#     -saveAll : false
#     -initkm : samp
#     -saveLabels :
# *** -saveSimpoints : /home/guest/xs-env/tutorial/07-checkpoint/result/cluster/stream_100000/simpoints0
# *** -saveSimpointWeights : /home/guest/xs-env/tutorial/07-checkpoint/result/cluster/stream_100000/weights0
#     -saveVectorWeights :
#     -saveInitCtrs :
#     -saveFinalCtrs :
#     -saveVectorsTxtFmt :
#     -saveVectorsBinFmt :
#     -saveProjMatrixTxtFmt :
#     -saveProjMatrixBinFmt :
#     -loadVectorsTxtFmt :
#     -loadVectorsBinFmt :
#     -loadProjMatrixTxtFmt :
#     -loadProjMatrixBinFmt :
#     -loadInitCtrs :
#     -loadInitLabels :
#     -loadVectorWeights :
# *** -inputVectorsGzipped : true
#     -fixedLength : on
#     -numFVs : -1
#     -FVDim : -1
#     -sampleSize : -1
# *** -seedkm : 353540
# *** -seedproj : 529570
#     -seedsample : 385089224
#     -verbose : 0
# -------------------------------------------------------------
#   Loading data from frequency vector file '/home/guest/xs-env/tutorial/07-checkpoint/result/profiling/stream_100000/simpoint_bbv.gz' (size: 13x11584)
#   Created random projection matrix (size: 11584x15)
#   Loaded and projected frequency vector file
#   Applying fixed-length vector weights (uniform weights)
#   Searching for best clustering for k <= 3
#
# --------------------------------------------------------------
# Run number 1 of at most 4, k = 1
# --------------------------------------------------------------
#   --------------------------------------------------------------
#   Initialization seed trial #1 of 2; initialization seed = 353540
#   --------------------------------------------------------------
#   Initialized k-means centers using random sampling: 1 centers
#   Number of k-means iterations performed: 1
#   BIC score: -48.3226
#   Distortion: 15.1846
#   Distortions/cluster: 15.1846
#   Variance: 1.26538
#   Variances/cluster: 1.26538
#   --------------------------------------------------------------
#   Initialization seed trial #2 of 2; initialization seed = 353541
#   --------------------------------------------------------------
#   Initialized k-means centers using random sampling: 1 centers
#   Number of k-means iterations performed: 1
#   BIC score: -48.3226
#   Distortion: 15.1846
#   Distortions/cluster: 15.1846
#   Variance: 1.26538
#   Variances/cluster: 1.26538
#   The best initialization seed trial was #1
#
# --------------------------------------------------------------
# Run number 2 of at most 4, k = 3
# --------------------------------------------------------------
#   --------------------------------------------------------------
#   Initialization seed trial #1 of 2; initialization seed = 353542
#   --------------------------------------------------------------
#   Initialized k-means centers using random sampling: 3 centers
#   Number of k-means iterations performed: 1
#   BIC score: -49.3334
#   Distortion: 8.98211
#   Distortions/cluster: 7.4127 1.56942 3.85186e-33
#   Variance: 0.898211
#   Variances/cluster: 1.05896 0.523139 0
#   --------------------------------------------------------------
#   Initialization seed trial #2 of 2; initialization seed = 353543
#   --------------------------------------------------------------
#   Initialized k-means centers using random sampling: 3 centers
#   Number of k-means iterations performed: 3
#   BIC score: -48.3705
#   Distortion: 8.81547
#   Distortions/cluster: 7.22065 0.935678 0.659141
#   Variance: 0.881547
#   Variances/cluster: 1.03152 0.935678 0.329571
#   The best initialization seed trial was #2
#
# --------------------------------------------------------------
# Run number 3 of at most 4, k = 2
# --------------------------------------------------------------
#   --------------------------------------------------------------
#   Initialization seed trial #1 of 2; initialization seed = 353544
#   --------------------------------------------------------------
#   Initialized k-means centers using random sampling: 2 centers
#   Number of k-means iterations performed: 1
#   BIC score: -48.023
#   Distortion: 11.5826
#   Distortions/cluster: 10.647 0.935678
#   Variance: 1.05297
#   Variances/cluster: 1.0647 0.935678
#   --------------------------------------------------------------
#   Initialization seed trial #2 of 2; initialization seed = 353545
#   --------------------------------------------------------------
#   Initialized k-means centers using random sampling: 2 centers
#   Number of k-means iterations performed: 1
#   BIC score: -51.4428
#   Distortion: 11.6993
#   Distortions/cluster: 10.1299 1.56942
#   Variance: 1.06357
#   Variances/cluster: 1.26623 0.523139
#   The best initialization seed trial was #1
#
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Post-processing runs
# ------------------------------------------------------------------
# ------------------------------------------------------------------
#   For the BIC threshold, the best clustering was run 3 (k = 2)
#   Post-processing run 3 (k = 2)
#     Saving simpoints of all non-empty clusters to file '/home/guest/xs-env/tutorial/07-checkpoint/result/cluster/stream_100000/simpoints0'
#     Saving weights of all non-empty clusters to file '/home/guest/xs-env/tutorial/07-checkpoint/result/cluster/stream_100000/weights0'

# %%
# %%bash
# source 07-checkpoint-env.sh >/dev/null
#
# CLUSTER=${RESULT_PATH}/cluster
# _LOG_PATH=${LOG_PATH}/checkpoint
# mkdir -p ${_LOG_PATH}
#
# $NEMU ${GCPT} \
#     -D ${RESULT_PATH} \
#     -w ${WORKLOAD} \
#     -C checkpoint \
#     -b \
#     -S ${CLUSTER} \
#     --cpt-interval ${CHECKPOINT_INTERVAL} \
#     > >(tee ${_LOG_PATH}/${WORKLOAD}-out.txt) 2> >(tee ${_LOG_PATH}/${WORKLOAD}-err.txt)
# Out:
# OpenSBI v1.5-23-gb9c091e
#    ____                    _____ ____ _____
#   / __ \                  / ____|  _ \_   _|
#  | |  | |_ __   ___ _ __ | (___ | |_) || |
#  | |  | | '_ \ / _ \ '_ \ \___ \|  _ < | |
#  | |__| | |_) |  __/ | | |____) | |_) || |_
#   \____/| .__/ \___|_| |_|_____/|____/_____|
#         | |
#         |_|
#
# Platform Name             : freechips,rocketchip-unknown
# Platform Features         : medeleg
# Platform HART Count       : 1
# Platform IPI Device       : aclint-mswi
# Platform Timer Device     : aclint-mtimer @ 1000000Hz
# Platform Console Device   : xlnx-uartlite
# Platform HSM Device       : ---
# Platform PMU Device       : ---
# Platform Reboot Device    : ---
# Platform Shutdown Device  : ---
# Platform Suspend Device   : ---
# Platform CPPC Device      : ---
# Firmware Base             : 0x80100000
# Firmware Size             : 327 KB
# Firmware RW Offset        : 0x40000
# Firmware RW Size          : 71 KB
# Firmware Heap Offset      : 0x49000
# Firmware Heap Size        : 35 KB (total), 2 KB (reserved), 9 KB (used), 23 KB (free)
# Firmware Scratch Size     : 4096 B (total), 408 B (used), 3688 B (free)
# Runtime SBI Version       : 2.0
#
# Domain0 Name              : root
# Domain0 Boot HART         : 0
# Domain0 HARTs             : 0*
# Domain0 Region00          : 0x0000000038000000-0x000000003800ffff M: (I,R,W) S/U: ()
# Domain0 Region01          : 0x0000000080140000-0x000000008015ffff M: (R,W) S/U: ()
# Domain0 Region02          : 0x0000000080100000-0x000000008013ffff M: (R,X) S/U: ()
# Domain0 Region03          : 0x000000003c000000-0x000000003fffffff M: (I,R,W) S/U: (R,W)
# Domain0 Region04          : 0x0000000000000000-0xffffffffffffffff M: () S/U: (R,W,X)
# Domain0 Next Address      : 0x0000000080200000
# Domain0 Next Arg1         : 0x0000000082300000
# Domain0 Next Mode         : S-mode
# Domain0 SysReset          : yes
# Domain0 SysSuspend        : yes
#
# Boot HART ID              : 0
# Boot HART Domain          : root
# Boot HART Priv Version    : v1.12
# Boot HART Base ISA        : rv64imafdcbvh
# Boot HART ISA Extensions  : smstateen,sscofpmf,sstc,zicntr
# Boot HART PMP Count       : 16
# Boot HART PMP Granularity : 12 bits
# Boot HART PMP Address Bits: 46
# Boot HART MHPM Info       : 0 (0x00000000)
# Boot HART Debug Triggers  : 0 triggers
# Boot HART MIDELEG         : 0x0000000000003666
# Boot HART MEDELEG         : 0x0000000000f0b509
# [    0.000000] Linux version 6.10.3 (liuzehao@open27) (riscv64-unknown-linux-gnu-gcc (g05b95238be6-dirty) 15.0.0 20240611 (experimental), GNU ld (GNU Binutils) 2.42) #12 SMP Sat Aug 17 17:30:08 CST 2024
# [    0.000000] Machine model: freechips,rocketchip-unknown
# [    0.000000] SBI specification v2.0 detected
# [    0.000000] SBI implementation ID=0x1 Version=0x10005
# [    0.000000] SBI TIME extension detected
# [    0.000000] SBI IPI extension detected
# [    0.000000] SBI RFENCE extension detected
# [    0.000000] SBI DBCN extension detected
# [    0.000000] earlycon: sbi0 at I/O port 0x0 (options '')
# [    0.000000] printk: legacy bootconsole [sbi0] enabled
# [    0.000000] efi: UEFI not found.
# [    0.000000] OF: reserved mem: 0x0000000080100000..0x000000008013ffff (256 KiB) nomap non-reusable mmode_resv1@80100000
# [    0.000000] OF: reserved mem: 0x0000000080140000..0x000000008015ffff (128 KiB) nomap non-reusable mmode_resv0@80140000
# [    0.000000] Zone ranges:
# [    0.000000]   DMA32    [mem 0x0000000080000000-0x00000000ffffffff]
# [    0.000000]   Normal   [mem 0x0000000100000000-0x000000027fffffff]
# [    0.000000] Movable zone start for each node
# [    0.000000] Early memory node ranges
# [    0.000000]   node   0: [mem 0x0000000080000000-0x00000000800fffff]
# [    0.000000]   node   0: [mem 0x0000000080100000-0x000000008015ffff]
# [    0.000000]   node   0: [mem 0x0000000080160000-0x000000027fffffff]
# [    0.000000] Initmem setup node 0 [mem 0x0000000080000000-0x000000027fffffff]
# [    0.000000] SBI HSM extension detected
# [    0.000000] Falling back to deprecated "riscv,isa"
# [    0.000000] riscv: base ISA extensions acdfhimv
# [    0.000000] riscv: ELF capabilities acdfimv
# [    0.000000] percpu: Embedded 13 pages/cpu s23648 r0 d29600 u53248
# [    0.000000] Kernel command line: console=hvc0 earlycon=sbi
# [    0.000000] Dentry cache hash table entries: 1048576 (order: 11, 8388608 bytes, linear)
# [    0.000000] Inode-cache hash table entries: 524288 (order: 10, 4194304 bytes, linear)
# [    0.000000] Built 1 zonelists, mobility grouping on.  Total pages: 2097152
# [    0.000000] mem auto-init: stack:all(zero), heap alloc:off, heap free:off
# [    0.000000] software IO TLB: area num 1.
# [    0.000000] software IO TLB: mapped [mem 0x00000000fbfff000-0x00000000fffff000] (64MB)
# [    0.000000] Memory: 8180520K/8388608K available (2005K kernel code, 4301K rwdata, 2048K rodata, 4141K init, 141K bss, 208088K reserved, 0K cma-reserved)
# [    0.000000] SLUB: HWalign=64, Order=0-3, MinObjects=0, CPUs=1, Nodes=1
# [    0.000000] rcu: Hierarchical RCU implementation.
# [    0.000000] rcu: 	RCU restricting CPUs from NR_CPUS=64 to nr_cpu_ids=1.
# [    0.000000] rcu: RCU calculated value of scheduler-enlistment delay is 25 jiffies.
# [    0.000000] rcu: Adjusting geometry for rcu_fanout_leaf=16, nr_cpu_ids=1
# [    0.000000] NR_IRQS: 64, nr_irqs: 64, preallocated irqs: 0
# [    0.000000] riscv-intc: 64 local interrupts mapped
# [    0.000000] riscv: providing IPIs using SBI IPI extension
# [    0.000000] rcu: srcu_init: Setting srcu_struct sizes based on contention.
# [    0.000000] clocksource: riscv_clocksource: mask: 0xffffffffffffffff max_cycles: 0x1d854df40, max_idle_ns: 3526361616960 ns
# [    0.000003] sched_clock: 64 bits at 1000kHz, resolution 1000ns, wraps every 2199023255500ns
# [    0.000623] Console: colour dummy device 80x25
# [    0.000794] Calibrating delay loop (skipped), value calculated using timer frequency.. 2.00 BogoMIPS (lpj=4000)
# [    0.000922] pid_max: default: 32768 minimum: 301
# [    0.001485] Mount-cache hash table entries: 16384 (order: 5, 131072 bytes, linear)
# [    0.001742] Mountpoint-cache hash table entries: 16384 (order: 5, 131072 bytes, linear)
# [    0.006820] riscv: ELF compat mode unsupported
# [    0.006866] ASID allocator using 16 bits (65536 entries)
# [    0.007379] rcu: Hierarchical SRCU implementation.
# [    0.007445] rcu: 	Max phase no-delay instances is 1000.
# [    0.008954] EFI services will not be available.
# [    0.009406] smp: Bringing up secondary CPUs ...
# [    0.009486] smp: Brought up 1 node, 1 CPU
# [    0.011648] clocksource: jiffies: mask: 0xffffffff max_cycles: 0xffffffff, max_idle_ns: 7645041785100000 ns
# [    0.011789] futex hash table entries: 256 (order: 2, 16384 bytes, linear)
# [    0.012052] DMA: preallocated 1024 KiB GFP_KERNEL pool for atomic allocations
# [    0.012262] DMA: preallocated 1024 KiB GFP_KERNEL|GFP_DMA32 pool for atomic allocations
# [    0.037170] cpu0: rdtime lacks granularity needed to measure unaligned access speed
# [    0.041728] clocksource: Switched to clocksource riscv_clocksource
# [    0.056190] workingset: timestamp_bits=62 max_order=21 bucket_order=0
# [    0.147321] riscv-plic 3c000000.interrupt-controller: mapped 64 interrupts with 1 handlers for 2 contexts.
# [    0.149086] printk: legacy console [hvc0] enabled
# [    0.149086] printk: legacy console [hvc0] enabled
# [    0.149237] printk: legacy bootconsole [sbi0] disabled
# [    0.149237] printk: legacy bootconsole [sbi0] disabled
# [    0.149481] Serial: 8250/16550 driver, 4 ports, IRQ sharing disabled
# [    0.152345] 40600000.serial: ttyUL0 at MMIO 0x40600000 (irq = 12, base_baud = 0) is a uartlite
# [    0.152686] uartlite 40600000.serial: Runtime PM usage count underflow!
# [    0.158742] clk: Disabling unused clocks
# [    0.756215] Freeing unused kernel image (initmem) memory: 4140K
# [    0.756355] Run /init as init process
# /
# bin          init         mnt          sbin         tmp
# dev          lib          proc         spec_common  usr
# etc          linuxrc      root         sys          var
# 12345
# -------------------------------------------------------------
# STREAM version $Revision: 5.10 $
# -------------------------------------------------------------
# This system uses 4 bytes per array element.
# -------------------------------------------------------------
# Array size = 10000000 (elements), Offset = 0 (elements)
# Memory per array = 38.1 MiB (= 0.0 GiB).
# Total memory required = 114.4 MiB (= 0.1 GiB).
# Each kernel will be executed 5 times.
#  The *best* time for each kernel (excluding the first iteration)
#  will be used to compute the reported bandwidth.
# -------------------------------------------------------------
# Your clock granularity/precision appears to be 511 microseconds.
# Each test below will take on the order of 351242 microseconds.
#    (= 687 clock ticks)
# Increase the size of the arrays if this shows that
# you are not getting at least 20 clock ticks per test.
# -------------------------------------------------------------
# WARNING -- The above is only a rough guideline.
# For best results, please be sure you know the
# precision of your system timer.
# -------------------------------------------------------------
# [src/monitor/monitor.c:198,parse_args] Taking simpoint checkpoints
# [src/checkpoint/path_manager.cpp:55,init] Cpt id: -1
# [src/checkpoint/serializer.cpp:507,init] Taking simpoint checkpionts with profiling interval 50000000
# [src/checkpoint/serializer.cpp:522,init] Simpoint 0: @ 5, weight: 0.846154
# [src/checkpoint/serializer.cpp:522,init] Simpoint 1: @ 12, weight: 0.153846
# [src/checkpoint/serializer.cpp:599,next_index] set next index 5
# [src/checkpoint/path_manager.cpp:90,setCheckpointingOutputDir] Created /home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/stream_100000/5/
#
# [src/isa/riscv64/init.c:229,init_isa] NEMU will start from pc 0x80000000
# [src/device/io/port-io.c:35,add_pio_map_with_diff] Add port-io map 'uartlite' at [0x00000000000003f8, 0x0000000000000404]
# [src/device/io/port-io.c:35,add_pio_map_with_diff] Add port-io map 'screen' at [0x0000000000000100, 0x0000000000000107]
# [src/device/io/port-io.c:35,add_pio_map_with_diff] Add port-io map 'keyboard' at [0x0000000000000060, 0x0000000000000063]
# [src/device/sdcard.c:137,init_sdcard] Can not find sdcard image:
# [src/monitor/image_loader.c:204,load_img] Loading image (checkpoint/bare metal app/bbl) form cmdline: /home/guest/xs-env/tutorial/07-checkpoint/gcpt/build/gcpt.bin
#
# [src/monitor/image_loader.c:260,load_img] Read 14937112 bytes from file /home/guest/xs-env/tutorial/07-checkpoint/gcpt/build/gcpt.bin to 0x0x100000000
# [src/monitor/monitor.c:63,welcome] Debug: OFF
# [src/monitor/monitor.c:68,welcome] Build time: 13:39:00, Jul 14 2025
# Welcome to riscv64-NEMU!
# For help, type "help"
# [/home/guest/xs-env/NEMU/src/isa/riscv64/include/../instr/special.h:38,execute] nemu_trap case 100
# [src/isa/riscv64/system/priv.c:1898,disable_time_intr] Disabled machine/supervisor/virtualized-supervisor time interruption
#
# [/home/guest/xs-env/NEMU/src/isa/riscv64/include/../instr/special.h:38,execute] nemu_trap case 101
# [src/profiling/profiling_control.c:22,start_profiling] Start profiling. Setting inst count base to Current inst count 269441690.
# [src/checkpoint/serializer.cpp:542,instrsCouldTakeCpt] Should take cpt now: 200000006 next point 200000000
# [src/checkpoint/serializer.cpp:335,serializeRegs] Writing int registers to checkpoint memory @[0xedde0, 0xedee0) [0xedde0, 0xedee0)
# [src/checkpoint/serializer.cpp:343,serializeRegs] Writing float registers to checkpoint memory @[0xedee8, 0xedfe8) [0xedee8, 0xedfe8)
# [src/checkpoint/serializer.cpp:354,serializeRegs] Writing Vector registers to checkpoint memory @[0xedee8, 0xedfe8) [0xfdff8, 0xfe1f8)
# [src/checkpoint/serializer.cpp:363,serializeRegs] Writing PC: 0x107a0 at addr 0xecdb8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x1: 0x1
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3: 0x1
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x105: 0xffffffff801f7318
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x106: 0x7
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x10a: 0xf0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x140: 0xffffaf8080178a40
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x141: 0x7fff8ce46eac
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x142: 0x8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x14d: 0x202d7f
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x180: 0x9000900000100ac2
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x200: 0x200000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x24d: 0xffffffffffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x300: 0xa000066a2
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x301: 0x80000000003411af
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x302: 0xf0b509
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x303: 0x3666
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x304: 0x20a
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x305: 0x80100500
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x306: 0xffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x30a: 0x80000000000000f0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x30c: 0xc200000000000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x320: 0xfffffff8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x340: 0x80148000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x341: 0xffffffff800091a8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x342: 0x9
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3a0: 0x1f1b181818
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b0: 0xe001fff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b1: 0x20053fff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b2: 0x20047fff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b3: 0xf7fffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b4: 0x3fffffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c0: 0x7f
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c1: 0x3d7b37
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c2: 0x30
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c3: 0x377
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c4: 0x5
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x600: 0x200000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x60a: 0x80000000000000f0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x744: 0x8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7c0: 0xb0b0b0f0b000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7c2: 0x186f0b080b0b0b0f
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cb: 0x4000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cc: 0x8000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cd: 0xc004000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7ce: 0xc014000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cf: 0xe008000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d0: 0xe008400
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d1: 0xe008800
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d2: 0xe400000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d3: 0xe400800
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d4: 0xe800000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d5: 0x20000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d6: 0x20000000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d7: 0x1fffffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xc20: 0x4
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xc21: 0xd0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xc22: 0x10
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xf12: 0x19
# [src/checkpoint/serializer.cpp:407,serializeRegs] Writing CSR to checkpoint memory @[0xedff0, 0xf5ff0) [0xedff0, 0xf5ff0)
# [src/checkpoint/serializer.cpp:415,serializeRegs] Touching Flag: 0xbeef at addr 0xecdb0
# [src/checkpoint/serializer.cpp:419,serializeRegs] Record mode flag: 0x0 at addr 0xecdc0
# [src/checkpoint/serializer.cpp:424,serializeRegs] Record time: 0x0 at addr 0xecdc8
# [src/checkpoint/serializer.cpp:428,serializeRegs] Record time: 0x0 at addr 0xecdd0
# [src/checkpoint/serializer.cpp:154,serializePMem] Host physical address: 0x100000000 size: 200000000
# [src/checkpoint/serializer.cpp:174,serializePMem] Using GZ format generate checkpoint
# Opening /home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/stream_100000/5/_5_0.846154_memory_.gz as memory checkpoint output file
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x4 bytes
#
# [src/checkpoint/serializer.cpp:320,serializePMem] Checkpoint done!
#
# [src/checkpoint/serializer.cpp:573,notify_taken] Taking checkpoint @ instruction count 200000006
# [src/checkpoint/serializer.cpp:575,notify_taken] simpoint2Weights size: 2
# [src/checkpoint/serializer.cpp:599,next_index] set next index 12
# [src/checkpoint/path_manager.cpp:90,setCheckpointingOutputDir] Created /home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/stream_100000/12/
#
# [src/checkpoint/serializer.cpp:619,try_take_cpt] return true
# [src/cpu/cpu-exec.c:374,per_bb_profile] Have taken checkpoint on pc 0x107a0
# [src/checkpoint/serializer.cpp:542,instrsCouldTakeCpt] Should take cpt now: 550000003 next point 550000000
# [src/checkpoint/serializer.cpp:335,serializeRegs] Writing int registers to checkpoint memory @[0xedde0, 0xedee0) [0xedde0, 0xedee0)
# [src/checkpoint/serializer.cpp:343,serializeRegs] Writing float registers to checkpoint memory @[0xedee8, 0xedfe8) [0xedee8, 0xedfe8)
# [src/checkpoint/serializer.cpp:354,serializeRegs] Writing Vector registers to checkpoint memory @[0xedee8, 0xedfe8) [0xfdff8, 0xfe1f8)
# [src/checkpoint/serializer.cpp:363,serializeRegs] Writing PC: 0x1086e at addr 0xecdb8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x1: 0x1
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3: 0x1
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x105: 0xffffffff801f7318
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x106: 0x7
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x10a: 0xf0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x140: 0xffffaf8080178a40
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x141: 0x7fff8ce46eac
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x142: 0x8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x14d: 0x202d7f
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x180: 0x9000900000100ac2
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x200: 0x200000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x24d: 0xffffffffffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x300: 0xa000066a2
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x301: 0x80000000003411af
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x302: 0xf0b509
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x303: 0x3666
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x304: 0x20a
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x305: 0x80100500
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x306: 0xffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x30a: 0x80000000000000f0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x30c: 0xc200000000000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x320: 0xfffffff8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x340: 0x80148000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x341: 0xffffffff800091a8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x342: 0x9
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3a0: 0x1f1b181818
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b0: 0xe001fff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b1: 0x20053fff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b2: 0x20047fff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b3: 0xf7fffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x3b4: 0x3fffffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c0: 0x7f
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c1: 0x3d7b37
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c2: 0x30
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c3: 0x377
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x5c4: 0x5
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x600: 0x200000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x60a: 0x80000000000000f0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x744: 0x8
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7c0: 0xb0b0b0f0b000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7c2: 0x186f0b080b0b0b0f
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cb: 0x4000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cc: 0x8000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cd: 0xc004000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7ce: 0xc014000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7cf: 0xe008000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d0: 0xe008400
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d1: 0xe008800
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d2: 0xe400000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d3: 0xe400800
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d4: 0xe800000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d5: 0x20000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d6: 0x20000000000
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0x7d7: 0x1fffffffffff
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xc20: 0x4
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xc21: 0xd0
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xc22: 0x10
# [src/checkpoint/serializer.cpp:386,serializeRegs] CSR 0xf12: 0x19
# [src/checkpoint/serializer.cpp:407,serializeRegs] Writing CSR to checkpoint memory @[0xedff0, 0xf5ff0) [0xedff0, 0xf5ff0)
# [src/checkpoint/serializer.cpp:415,serializeRegs] Touching Flag: 0xbeef at addr 0xecdb0
# [src/checkpoint/serializer.cpp:419,serializeRegs] Record mode flag: 0x0 at addr 0xecdc0
# [src/checkpoint/serializer.cpp:424,serializeRegs] Record time: 0x0 at addr 0xecdc8
# [src/checkpoint/serializer.cpp:428,serializeRegs] Record time: 0x0 at addr 0xecdd0
# [src/checkpoint/serializer.cpp:154,serializePMem] Host physical address: 0x100000000 size: 200000000
# [src/checkpoint/serializer.cpp:174,serializePMem] Using GZ format generate checkpoint
# Opening /home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/stream_100000/12/_12_0.153846_memory_.gz as memory checkpoint output file
# Function    Best Rate MB/s  Avg time     Min time     Max time
# Copy:            4595.3     0.017409     0.017409     0.017410
# Scale:            455.5     0.175621     0.175621     0.175622
# Add:              559.3     0.214919     0.214535     0.215047
# Triad:            559.4     0.214662     0.214534     0.215046
# -------------------------------------------------------------
# Solution Validates: avg error less than 1.000000e-06 on all three arrays
# -------------------------------------------------------------
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x7fffffff bytes
#
# [src/checkpoint/serializer.cpp:221,serializePMem] Written 0x4 bytes
#
# [src/checkpoint/serializer.cpp:320,serializePMem] Checkpoint done!
#
# [src/checkpoint/serializer.cpp:573,notify_taken] Taking checkpoint @ instruction count 550000003
# [src/checkpoint/serializer.cpp:575,notify_taken] simpoint2Weights size: 1
# [src/checkpoint/serializer.cpp:619,try_take_cpt] return true
# [src/cpu/cpu-exec.c:374,per_bb_profile] Have taken checkpoint on pc 0x1086e
# [/home/guest/xs-env/NEMU/src/isa/riscv64/include/../instr/special.h:38,execute] nemu_trap case 0
# [src/cpu/cpu-exec.c:916,cpu_exec] nemu: HIT GOOD TRAP at pc = 0x00000000000103b4
# [src/cpu/cpu-exec.c:922,cpu_exec] trap code:0
# [src/cpu/cpu-exec.c:155,monitor_statistic] host time spent = 43718886 us
# [src/cpu/cpu-exec.c:157,monitor_statistic] total guest instructions = 925335065
# [src/cpu/cpu-exec.c:158,monitor_statistic] vst count = 46588127, vst unit count = 46588127, vst unit optimized count = 41363440
# [src/cpu/cpu-exec.c:161,monitor_statistic] simulation frequency = 21165568 instr/s
# [src/utils/state.c:30,is_exit_status_bad] NEMU exit with good state: 2, halt ret: 0

# %%
# %%bash
# source 07-checkpoint-env.sh >/dev/null
#
# CHECKPOINT=$(find ${RESULT_PATH}/checkpoint/${WORKLOAD} -type f -name "*_.gz" | tail -1)
#
# ${NOOP_HOME}/emu \
#     -i ${CHECKPOINT} \
#     --diff ${NOOP_HOME}/ready-to-run/riscv64-nemu-interpreter-so \
#     --max-cycles=50000 \
#     2>/dev/null
# Out:
# emu compiled at Jul  9 2025, 13:02:33
# Using simulated 32768B flash
# Core  0's Commit SHA is: 6933700098, dirty: 0
# Using simulated 8386560MB RAM
# The image is /home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/stream_100000/12/_12_0.153846_memory_.gz
# Gzip file detected and loading image from extracted gz file
# The reference model is /home/guest/xs-env/XiangShan/ready-to-run/riscv64-nemu-interpreter-so
# The first instruction of core 0 has commited. Difftest enabled.
# Core 0: EXCEEDING CYCLE/INSTR LIMIT at pc = 0x10884
# Core-0 instrCnt = 18301, cycleCnt = 50000, IPC = 0.366020
# Seed=0 Guest cycle spent: 50005 (this will be different from cycleCnt if emu loads a snapshot)
# Host time spent: 23108ms

# %%
import os
import re
import json
from pathlib import Path
from itertools import product

app_list = [
    "bwaves", "gamess_cytosine", "gamess_gradient", "gamess_triazolium",
    "milc", "zeusmp", "gromacs", "cactusADM", "leslie3d", "namd", "dealII",
    "soplex_pds-50", "soplex_ref", "povray", "calculix", "GemsFDTD", "tonto",
    "lbm", "wrf", "sphinx3"
]

spec_2017_list = [
    "bwaves_1", "bwaves_2", "bwaves_3", "bwaves_4", "cactuBSSN", "namd",
    "parest", "povray", "lbm", "wrf", "blender", "cam4", "imagick", "nab",
    "fotonik3d", "roms", "perlbench_diff", "perlbench_spam", "perlbench_split",
    "gcc_pp_O2", "gcc_pp_O3", "gcc_ref32_O3", "gcc_ref32_O5", "gcc_small_O3",
    "mcf", "omnetpp", "xalancbmk", "x264_pass1", "x264_pass2", "x264_seek",
    "deepsjeng", "leela", "exchange2", "xz_cld", "xz_combined", "xz_cpu2006"
]

spec2017_int_list = [
    "perlbench_diff", "perlbench_spam", "perlbench_split", "gcc_pp_O2",
    "gcc_pp_O3", "gcc_ref32_O3", "gcc_ref32_O5", "gcc_small_O3", "mcf",
    "omnetpp", "xalancbmk", "x264_pass1", "x264_pass2", "x264_seek",
    "deepsjeng", "leela", "exchange2", "xz_cld", "xz_combined", "xz_cpu2006"
]

spec2017_fp_list = list(set(spec_2017_list) - set(spec2017_int_list))


def profiling_instrs(profiling_log, spec_app, using_new_script=False):
    regex = r".*total guest instructions = (.*)\x1b.*"
    new_path = os.path.join(profiling_log, spec_app, "profiling.out.log")
    old_path = os.path.join(profiling_log, "{}-out.txt".format(spec_app))

    if using_new_script:
        path = new_path
    else:
        path = old_path

    with open(path, "r", encoding="utf-8") as f:
        for i in f.readlines():
            if "total guest instructions" in i:
                match = re.findall(regex, i)
                match = match[0].replace(',', '')
                return match
        return 0


def cluster_weight(cluster_path, spec_app):
    points = {}
    weights = {}

    weights_path = f"{cluster_path}/{spec_app}/weights0"
    simpoints_path = f"{cluster_path}/{spec_app}/simpoints0"

    with open(weights_path, "r") as f:
        for line in f.readlines():
            a, b = line.split()
            weights.update({"{}".format(b): "{}".format(a)})

    with open(simpoints_path, "r") as f:
        for line in f.readlines():
            a, b = line.split()
            points.update({a: weights.get(b)})

    return points


def per_checkpoint_generate_json(profiling_log, cluster_path, app_list,
                                 target_path):
    result = {}
    for spec in app_list:
        result.update({
            spec: {
                "insts": profiling_instrs(profiling_log, spec),
                'points': cluster_weight(cluster_path, spec)
            }
        })
    with open(os.path.join(target_path), "w") as f:
        f.write(json.dumps(result))


def per_checkpoint_generate_worklist(cpt_path, target_path):
    cpt_path = cpt_path + "/"
    checkpoints = []
    for item in os.scandir(cpt_path):
        if item.is_dir():
            checkpoints.append(item.path)

    checkpoint_dirs = []
    for item in checkpoints:
        for entry in os.scandir(item):
            checkpoint_dirs.append(entry.path)

    with open(target_path, "w") as f:
        for i in checkpoint_dirs:
            path = i.replace(cpt_path, "")
            name = path.replace('/', "_", 1)
            print("{} {} 0 0 20 20".format(name, path), file=f)


def generate_result_list(base_path, times, ids):
    result_list = []

    for i, j, k in product(range(ids[0], times[0]), range(ids[1], times[1]),
                           range(ids[2], times[2])):
        cluster = f"cluster"
        profiling = f"profiling"
        checkpoint = f"checkpoint"
        result_list.append({
            "cl_res": os.path.join(base_path, "result", cluster),
            "profiling_log": os.path.join(base_path, "logs", profiling),
            "checkpoint_path": os.path.join(base_path, "result", checkpoint),
            "json_path": os.path.join(base_path, "result", checkpoint, f"{cluster}.json"),
            "list_path": os.path.join(base_path, "result", checkpoint, "checkpoint.lst"),
        })

    print("Result list:")
    print(json.dumps(result_list, indent=2, separators=(",", ": ")))
    return result_list



def dump_result(base_path, spec_app_list, times, ids):
    result_list = generate_result_list(base_path, times, ids)

    for result in result_list:
        per_checkpoint_generate_json(result["profiling_log"], result["cl_res"],
                                     spec_app_list, result["json_path"])
        per_checkpoint_generate_worklist(result["checkpoint_path"],
                                         result["list_path"])


# NOTE: should be same with 07-checkpoint-env.sh
spec_list=["stream_100000"]
base_path = os.path.join(os.getcwd(), "07-checkpoint")
times = [1, 1, 1]
ids = [0, 0, 0]

dump_result(base_path, spec_list, times, ids)
# Out:
# Result list:
# [
#   {
#     "cl_res": "/home/guest/xs-env/tutorial/07-checkpoint/result/cluster",
#     "profiling_log": "/home/guest/xs-env/tutorial/07-checkpoint/logs/profiling",
#     "checkpoint_path": "/home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint",
#     "json_path": "/home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/cluster.json",
#     "list_path": "/home/guest/xs-env/tutorial/07-checkpoint/result/checkpoint/checkpoint.lst"
#   }
# ]
